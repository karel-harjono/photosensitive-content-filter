# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math

# %%
def analyze_video(path):
    cap = cv2.VideoCapture(path)
    # Check if camera opened successfully
    if (cap.isOpened()== False): 
        print("Error opening video stream or file")

    timestamp = 0
    mean_intensity = []
    # Read until video is completed
    while(cap.isOpened()):
        # Capture frame-by-frame
        ret, frame = cap.read()
        if ret == True:
            red = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            mean_intensity.append(cv2.mean(red)[0]) # red is the first dimension so take the first element
            # Display the resulting frame
            # cv2.imshow('Frame',frame)

            # Press Q on keyboard to  exit
            # if cv2.waitKey(25) & 0xFF == ord('q'):
            #   break
            timestamp = timestamp + 1
        # Break the loop
        else: 
            break
    metadata = {
        'frame_count': cap.get(cv2.CAP_PROP_FRAME_COUNT),
        'fps': cap.get(cv2.CAP_PROP_FPS),
        'frame_width': cap.get(cv2.CAP_PROP_FRAME_WIDTH),   # float `width`
        'frame_height': cap.get(cv2.CAP_PROP_FRAME_HEIGHT)  # float `height`
    }
    # When everything done, release the video capture object
    cap.release()

    # Closes all the frames
    cv2.destroyAllWindows()

    return [range(1, timestamp+1), mean_intensity, metadata,red]

def show(x, y, xlabel, ylabel, start=None, end=None):
    fig, ax = plt.subplots()
    ax.plot(x[start:end], y[start:end])
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    plt.show()

# %%
# plot mean red intensity to frames
x, y, metadata,red = analyze_video('../../videos/reference/red_strobe_ref.mp4')
show(x, y, 'frames', 'mean intensity(0-255)')

# %% [markdown]
# Here, we can see that our function was able to detect the high intensity of red color in each frame. We expect it to have a high jump between frames.

# %%
diff = []
for i in range(len(y)-1):
    diff.append(1 if abs(y[i] - y[i+1]) > 200 else 0) # TODO: figure out tuning metrics
diff.append(0) # adjust shape for plotting

# %%
def detectUnsafeFlashesFrame(intensity, fps, max_flashes=3):
    warning_count = 0
    count = 0
    ## added count to show all flashes within the video in a 5 frame range
    for i in range(len(intensity) - fps):
        num_flash = np.sum(intensity[i:i+fps])
        if(num_flash > max_flashes and count == 0):
            print(f"{num_flash} flashes detected at seconds: {math.ceil(i/30)+1}")
            warning_count = warning_count + 1                
        count = count + 1
        if(count >= fps) : count = 0        
    return warning_count, i

detectUnsafeFlashesFrame(diff, int(metadata['fps']), max_flashes=5)
# Out:
# 14 flashes detected at seconds: 1
# 15 flashes detected at seconds: 2
# 14 flashes detected at seconds: 3
# 15 flashes detected at seconds: 4
# 14 flashes detected at seconds: 5
# 15 flashes detected at seconds: 6
# 14 flashes detected at seconds: 7
# 15 flashes detected at seconds: 8
# 14 flashes detected at seconds: 9
# 15 flashes detected at seconds: 10
# 14 flashes detected at seconds: 11
# 15 flashes detected at seconds: 12
# 14 flashes detected at seconds: 13
# 15 flashes detected at seconds: 14
# 14 flashes detected at seconds: 15
# 15 flashes detected at seconds: 16
# 14 flashes detected at seconds: 17
# 15 flashes detected at seconds: 18
# 14 flashes detected at seconds: 19
# 15 flashes detected at seconds: 20
# 14 flashes detected at seconds: 21
# 15 flashes detected at seconds: 22
# 14 flashes detected at seconds: 23
# 14 flashes detected at seconds: 525
# 15 flashes detected at seconds: 526
# 14 flashes detected at seconds: 527
# 15 flashes detected at seconds: 528
# 14 flashes detected at seconds: 529
# 15 flashes detected at seconds: 530
# 14 flashes detected at seconds: 531
# 15 flashes detected at seconds: 532
# 14 flashes detected at seconds: 533
# 15 flashes detected at seconds: 534
# 14 flashes detected at seconds: 535
# 15 flashes detected at seconds: 536
# 14 flashes detected at seconds: 537
# 15 flashes detected at seconds: 538
# 14 flashes detected at seconds: 539
# 15 flashes detected at seconds: 540
# 14 flashes detected at seconds: 541
# 15 flashes detected at seconds: 542
# 14 flashes detected at seconds: 543
# 15 flashes detected at seconds: 544
# 14 flashes detected at seconds: 545
# 15 flashes detected at seconds: 546
# 14 flashes detected at seconds: 547
# 15 flashes detected at seconds: 548
# 14 flashes detected at seconds: 549
# 15 flashes detected at seconds: 550
# 14 flashes detected at seconds: 551
# 15 flashes detected at seconds: 552
# 14 flashes detected at seconds: 552
# 15 flashes detected at seconds: 553
# 14 flashes detected at seconds: 554
# 15 flashes detected at seconds: 555
# 14 flashes detected at seconds: 556
# 15 flashes detected at seconds: 557
# 14 flashes detected at seconds: 558
# 15 flashes detected at seconds: 559
# 14 flashes detected at seconds: 560
# 15 flashes detected at seconds: 561
# 14 flashes detected at seconds: 562
# 15 flashes detected at seconds: 563
# 14 flashes detected at seconds: 564
# 15 flashes detected at seconds: 565
# 14 flashes detected at seconds: 566
# 15 flashes detected at seconds: 567
# 14 flashes detected at seconds: 568
# 15 flashes detected at seconds: 569
# 14 flashes detected at seconds: 570
# 15 flashes detected at seconds: 571
# 14 flashes detected at seconds: 572
# 15 flashes detected at seconds: 573
# 14 flashes detected at seconds: 574
# 15 flashes detected at seconds: 575
# 14 flashes detected at seconds: 576
# 15 flashes detected at seconds: 577
# 14 flashes detected at seconds: 578
# 15 flashes detected at seconds: 579
# 14 flashes detected at seconds: 580
# 15 flashes detected at seconds: 581
# 14 flashes detected at seconds: 581
# 15 flashes detected at seconds: 582
# 14 flashes detected at seconds: 583
# 15 flashes detected at seconds: 584
# 14 flashes detected at seconds: 585
# 15 flashes detected at seconds: 586
# 14 flashes detected at seconds: 587
# 15 flashes detected at seconds: 588
# 14 flashes detected at seconds: 589
# 15 flashes detected at seconds: 590
# 14 flashes detected at seconds: 591
# 15 flashes detected at seconds: 592
# 14 flashes detected at seconds: 593
# 15 flashes detected at seconds: 594
# 14 flashes detected at seconds: 595
# 15 flashes detected at seconds: 596
# 14 flashes detected at seconds: 597
# 15 flashes detected at seconds: 598
# 14 flashes detected at seconds: 599
# (619, 17923)

# %%
# plot mean red intensity to frames
x, y, metadata,blue = analyze_video('../../videos/reference/blue_strobe_ref.mp4')
show(x, y, 'frames', 'mean intensity(0-255)')

# %% [markdown]
# We expect our function would detect zero red color in the video. This plot shows that the function does detect the color red albeit a small amount. This does not hinder our program in detecting blue flashes. Hence, we can determine our function as a success.
